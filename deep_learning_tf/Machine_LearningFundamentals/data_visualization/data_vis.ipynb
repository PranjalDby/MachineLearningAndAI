# %%
#showing regression relationship betweent two variable using line graph
import matplotlib.pyplot as plt # type: ignore
import numpy as np
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
# plt.plot(xs,ys,ls="-.",color='red',linewidth=3)
# plt.xlabel("X-axis")
# plt.ylabel("Y-axis")

# plt.title("Simple Line Plot")
# plt.show()

# %% [markdown]
# ### SHOWING ONLY "Y POINTS" WITH FMT PARAMATER MARKER|LINE|COLOR

# %%
xs_new = 1 + 2.5 * np.random.randn(5)
ys_new = 2 - 1.5 * np.random.randn(5)
print("xs_new = ",xs_new)
print("ys_new = ",ys_new)
# mec :: marker edge color
# ms :: marker size
# mfc :: marker face color
plt.plot(xs_new,ys_new,'*-y',mec='r')
plt.grid(True)
plt.xlabel("x-axis",fontdict={"family":"serif","color":'violet','size':20})
plt.ylabel("y-axis")
plt.show()
# Out:
# xs_new =  [-2.50414954 -3.6303388   0.7926076   0.75013322  1.76145451]
# ys_new =  [ 2.48448271  0.19147232  3.09952628  1.4811259  -1.33957783]

# %%
plt.subplot(1,2,1)## plotting multiple figures within the same plot
#here 1:no of rows 2:no of columns and 1:index(plot number)
plt.plot(xs_new,':r')
plt.plot(ys_new,'-.y')
# Rotate x-axis and y-axis tick labels by 45 degrees
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.show()

# %%
## bar plots

sold = np.random.randint(0,1000,4)
x_items = ["PC","TV","Refrigerator","Micro"]

# plt.bar(x_items,sold,width=0.2) # it supports width
plt.barh(x_items,sold,color='red')
plt.xlabel("items")
plt.ylabel("sales in (1000 s)")
plt.grid(True)
plt.show()

# %% [markdown]
# # Important Plots and Graphs in Matplotlib
#
# Matplotlib is a powerful Python library for data visualization. Here are some of the most important plots and graphs you can create with matplotlib:
#
# ## 1. Line Plot
# - **Purpose:** Visualize the relationship between two variables, typically continuous data.
# - **Usage:** `plt.plot(x, y)`
# - **Example:** Showing trends over time or regression relationships.
#
# ## 2. Scatter Plot
# - **Purpose:** Show the relationship between two sets of data using points.
# - **Usage:** `plt.scatter(x, y)`
# - **Example:** Visualizing correlation or clustering in data.
#
# ## 3. Bar Plot
# - **Purpose:** Compare quantities corresponding to different groups or categories.
# - **Usage:** `plt.bar(categories, values)` or `plt.barh(categories, values)`
# - **Example:** Comparing sales of different products.
#
# ## 4. Histogram
# - **Purpose:** Display the distribution of a dataset.
# - **Usage:** `plt.hist(data, bins=number_of_bins)`
# - **Example:** Understanding the frequency distribution of exam scores.
#
# ## 5. Pie Chart
# - **Purpose:** Show proportions of a whole.
# - **Usage:** `plt.pie(sizes, labels=labels)`
# - **Example:** Market share of different companies.
#
# ## 6. Box Plot
# - **Purpose:** Summarize data using quartiles and identify outliers.
# - **Usage:** `plt.boxplot(data)`
# - **Example:** Comparing distributions between several groups.
#
# ## 7. Subplots
# - **Purpose:** Display multiple plots in a single figure for comparison.
# - **Usage:** `plt.subplot(rows, cols, index)`
# - **Example:** Comparing different visualizations side by side.
#
# ---
#
# **Tips:**
# - Customize plots with titles, labels, legends, and colors.
# - Use `plt.grid(True)` for better readability.
# - Save figures using `plt.savefig('filename.png')`.
#
# Matplotlib offers flexibility and control for creating publication-quality visualizations in Python.

# %%
exam_scores = np.random.randint(0,100,size=10)

plt.hist(exam_scores,bins=4)
plt.ylabel("frequency")
plt.xlabel("MARKS")
plt.show()

# %% [markdown]
# #SUBPLOTS

# %%
x = [1,2,3,4,5]
y1 = [2,3,5,7,11]
y2 = [1,4,6,8,11]
# plt.subplots() ## it will return a tuple of objects (figure and plots)
fig, axs_plots = plt.subplots(2)
#axs_plots here represent horizontal axis means (axis = 0)
axs_plots[0].plot(x,y1) # 0 represents index
axs_plots[0].set_title("First Plot")
axs_plots[1].plot(x,y2,'-r')
axs_plots[1].annotate("Peak",xy=(5,11),xytext=(4.5,9),arrowprops=dict(facecolor='blue',shrink=0.05))
axs_plots[1].set_title("Second Plot")
plt.tight_layout(pad=0.8)
## annotating the plot
plt.show()

# %% [markdown]
# ### SEABORN

# %%
import seaborn as sbn

# %%
## plotting with seaborn

x = np.random.randint(100,size=10)
y = np.random.randint(50,size=10)

## lineplot
sbn.lineplot(x =x ,y =y)
plt.xlabel("X-axis")
plt.ylabel("y-axis")
plt.title("Simple Line plot with Seaborn")
plt.show()

# %%
import tensorflow as tf;
from tensorflow.keras.datasets import fashion_mnist # type:ignore
# Out:
# 2025-06-20 05:47:43.539794: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750398463.691022    1980 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750398463.735442    1980 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1750398464.037565    1980 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
(X_train,y_train),(X_test,y_test) = fashion_mnist.load_data()

# %%
X_train.shape

# taking look on 10 images
for imgs in range(1,10):
    plt.subplot(2,5,imgs)
    plt.tight_layout(pad=0.7)
    plt.imshow(X_train[imgs])

plt.show()

# %%
from sklearn.datasets import load_iris

##loaded the iris dataset
iris = load_iris()
iris_data = sbn.load_dataset("iris")
sbn.pairplot(iris_data,hue='species')
plt.title("Focusing on Species",y=0.4,loc='right')
plt.show()

# %%
import pandas as pd
sales_df = pd.read_csv('sales_data.csv')
print(sales_df.head())
# Out:
#    Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0        1052  2023-02-03       Bob  North       5053.97             18
# 1        1093  2023-04-21       Bob   West       4384.02             17
# 2        1015  2023-09-21     David  South       4631.23             30
# 3        1072  2023-08-24       Bob  South       2167.94             39
# 4        1061  2023-03-24   Charlie   East       3750.20             13
#
#   Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# 0        Furniture     152.75      267.22     Returning      0.09
# 1        Furniture    3816.39     4209.44     Returning      0.11
# 2             Food     261.56      371.40     Returning      0.20
# 3         Clothing    4330.03     4467.75           New      0.02
# 4      Electronics     637.37      692.71           New      0.08
#
#   Payment_Method Sales_Channel Region_and_Sales_Rep
# 0           Cash        Online            North-Bob
# ...

# %%
import plotly.express as ply

# %%
fig = ply.line(data_frame=sales_df,x='Sale_Date',y='Sales_Amount',title="Sales Vs Time",markers=True)
fig.show()

# %%
#bar-plots shows the comparison b/w different categories
fig = ply.bar(sales_df,x="Quantity_Sold",y="Sales_Amount",color='Region_and_Sales_Rep')
fig.show()

# %%
# PIE-CHART
fig = ply.pie(data_frame=sales_df,names='Product_Category',title="Sales Distribution by Product")
fig.show()

# %%
# line plot(shows the trend highlights)
# sales line per sales reprs
fig = ply.line(data_frame=sales_df,x='Region_and_Sales_Rep',y='Sales_Amount',hover_data=['Product_Category','Quantity_Sold'])
fig.show()
